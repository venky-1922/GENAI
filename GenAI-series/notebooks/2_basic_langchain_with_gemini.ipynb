# %% [markdown]
# Connect with google gemini

# %%
from dotenv import load_dotenv
load_dotenv()
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
result = llm.invoke("What it Langchain ?")
print(result)
# Out:
# content='LangChain is an **open-source framework designed to simplify the development of applications powered by large language models (LLMs)**. Think of it as a toolkit that helps you connect LLMs to other data sources and allows them to interact with their environment.\n\nHere\'s a breakdown of what LangChain is and why it\'s important:\n\n**The Core Problem LangChain Solves:**\n\nLLMs are powerful on their own, but they are often isolated. They can generate text, answer questions based on their training data, and perform various language tasks. However, to build truly useful and sophisticated applications, you need to:\n\n*   **Provide them with external knowledge:** LLMs don\'t inherently know about your specific documents, databases, or real-time information.\n*   **Enable them to take action:** You might want an LLM to browse the web, execute code, or interact with APIs.\n*   **Structure complex workflows:** Building applications that involve multiple LLM calls, data retrieval, and decision-making can become very intricate.\n\n**How LangChain Helps:**\n\nLangChain provides a structured and modular way to overcome these limitations. It offers a set of components and abstractions that allow developers to:\n\n1.  **Connect LLMs to Data:**\n    *   **Document Loaders:** Easily load data from various sources like files (PDFs, text, CSVs), websites, databases, and more.\n    *   **Text Splitters:** Break down large documents into smaller, manageable chunks for LLMs to process efficiently.\n    *   **Vector Stores:** Store and retrieve text embeddings (numerical representations of text) for efficient similarity search. This is crucial for RAG (Retrieval Augmented Generation).\n\n2.  **Enable LLM Interaction with the Environment:**\n    *   **Agents:** These are the "brains" of your LangChain application. Agents use LLMs to reason about what actions to take and in what order. They can decide to use tools to achieve a goal.\n    *   **Tools:** These are functions or APIs that an LLM can call. Examples include:\n        *   Search engines (Google Search, DuckDuckGo)\n        *   Calculators\n        *   Databases\n        *   APIs (weather, stock prices, etc.)\n        *   Code interpreters\n\n3.  **Orchestrate LLM Workflows:**\n    *   **Chains:** Chains allow you to combine multiple LLM calls and other components into a coherent sequence. This is fundamental for building complex applications. For example, you might have a chain that first retrieves information from a document, then uses an LLM to summarize it, and finally uses another LLM to answer a question based on the summary.\n    *   **Memory:** LangChain provides mechanisms for LLMs to "remember" past interactions within a conversation, allowing for more context-aware and coherent dialogues.\n\n**Key Concepts in LangChain:**\n\n*   **LLMs:** The core language models you\'re interacting with (e.g., OpenAI\'s GPT models, Anthropic\'s Claude, Hugging Face models).\n*   **Prompts:** The instructions and context you provide to the LLM. LangChain offers sophisticated prompt templating.\n*   **Output Parsers:** Tools to structure the output of LLMs into specific formats (like JSON, lists, etc.).\n*   **Callbacks:** Mechanisms to observe and interact with the intermediate steps of a LangChain run.\n\n**Why is LangChain Popular?**\n\n*   **Developer Productivity:** It abstracts away a lot of the boilerplate code needed to integrate LLMs, allowing developers to focus on application logic.\n*   **Modularity and Composability:** The framework is built with reusable components, making it easy to mix and match different parts to create custom solutions.\n*   **Flexibility:** Supports a wide range of LLMs, data sources, and tools.\n*   **Active Community:** Being open-source, it benefits from a large and active community contributing to its development and providing support.\n*   **Enabling Advanced Use Cases:** It\'s the backbone for many cutting-edge LLM applications like:\n    *   ** ...

# %% [markdown]
# Static prompts

# %%
prompt = [
    ("system", "You are a Langchain expert."),
    ("user","What are the important topics to learn in Langchain ?")
]
result = llm.invoke(prompt)
print(result)
# Out:
# content="As a Langchain expert, I can tell you that Langchain is a rapidly evolving framework, and staying on top of its key components is crucial for building powerful LLM-powered applications. Here are the most important topics to learn in Langchain, categorized for clarity:\n\n**I. Core Concepts & Building Blocks:**\n\n*   **LLMs (Large Language Models):**\n    *   Understanding different LLM providers (OpenAI, Hugging Face, Anthropic, etc.) and how to interact with them.\n    *   Key concepts like prompts, tokens, temperature, and top-p sampling.\n    *   Finetuning and its implications (though Langchain primarily focuses on *using* pre-trained models).\n*   **Prompts:**\n    *   **Prompt Engineering:** The art and science of crafting effective prompts to guide LLMs.\n    *   **Prompt Templates:** How to dynamically create prompts with placeholders for context and variables.\n    *   **Chat Prompt Templates:** Specifically for conversational LLMs, handling roles (system, human, AI).\n*   **Chains:**\n    *   **Sequential Chains:** The fundamental concept of linking LLMs and other components together in a sequence.\n    *   **LLMChain:** The most basic chain, combining an LLM with a prompt.\n    *   **`SimpleSequentialChain`:** For simple, linear chains where output of one step is input to the next.\n    *   **`SequentialChain`:** For more complex chains with multiple inputs and outputs.\n    *   **Custom Chains:** Understanding how to build your own chain logic.\n*   **Agents:**\n    *   **What are Agents?** LLMs that can reason and decide which tools to use to accomplish a task.\n    *   **Tools:** Functions or APIs that an agent can call (e.g., search engines, calculators, databases).\n    *   **Agent Types:**\n        *   **`zero-shot-react-description`:** A common and powerful agent type.\n        *   **`conversational-react-description`:** For agents that maintain conversation history.\n        *   **`openai-functions`:** Leverages OpenAI's function calling capabilities.\n        *   **`openai-tools`:** Similar to `openai-functions` but for newer OpenAI models.\n    *   **Agent Executors:** The runtime that manages the agent's decision-making process.\n*   **Memory:**\n    *   **Purpose of Memory:** Allowing LLM applications to remember past interactions.\n    *   **Types of Memory:**\n        *   **`ConversationBufferMemory`:** Stores the raw conversation.\n        *   **`ConversationBufferWindowMemory`:** Stores a fixed number of recent messages.\n        *   **`ConversationSummaryMemory`:** Summarizes the conversation.\n        *   **`ConversationSummaryBufferMemory`:** Combines summarization with a buffer.\n        *   **`VectorStoreRetrieverMemory`:** Uses a vector store to retrieve relevant past interactions.\n    *   **Integrating Memory into Chains and Agents.**\n\n**II. Data Integration & Retrieval:**\n\n*   **Document Loaders:**\n    *   Loading data from various sources (files, websites, databases, APIs).\n    *   Understanding different loader implementations (e.g., `TextLoader`, `WebBaseLoader`, `PyPDFLoader`).\n*   **Text Splitters:**\n    *   Breaking down large documents into smaller, manageable chunks for LLM processing.\n    *   Different splitting strategies (character, recursive character, token-aware).\n*   **Vector Stores:**\n    *   **Embeddings:** Converting text into numerical vectors that capture semantic meaning.\n    *   **Vector Databases:** Storing and querying these embeddings efficiently (e.g., Chroma, Pinecone, FAISS, Weaviate).\n    *   **`VectorStoreRetriever`:** The core component for retrieving relevant documents based on a query embedding.\n*   **Retrieval Augmented Generation (RAG):**\n    *   The fundamental pattern of retrieving relevant information from a knowledge base and using it to augment LLM prompts.\n    *   Understanding the RAG pipeline: document loading -> splitting -> embedding -> storing -> retrieval -> generation.\n\n**III. Advanced & Specialized Topics:**\n\n*    ...
