# %% [markdown]
# Connect with google gemini

# %%
from dotenv import load_dotenv
load_dotenv()
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
result = llm.invoke("What it Langchain ?")
print(result)
# Out:
# content='Langchain is a **framework designed to help developers build applications powered by large language models (LLMs)**. Think of it as a toolkit that simplifies the process of connecting LLMs to external data sources and enabling them to perform more complex tasks than just generating text.\n\nHere\'s a breakdown of what Langchain is and why it\'s important:\n\n**The Core Problem Langchain Solves:**\n\nLLMs are incredibly powerful for generating human-like text, answering questions, and performing various language-based tasks. However, they have limitations:\n\n*   **Limited Knowledge:** LLMs are trained on a massive dataset, but their knowledge is static and doesn\'t include real-time or private information.\n*   **Lack of Memory:** LLMs are stateless; they don\'t remember past interactions within a conversation.\n*   **Difficulty with Complex Workflows:** Orchestrating multiple LLM calls, interacting with external tools, and managing data flow can be cumbersome to build from scratch.\n\n**How Langchain Addresses These Problems:**\n\nLangchain provides a structured and modular approach to overcome these limitations by offering components and abstractions for:\n\n1.  **Connecting LLMs to External Data (Retrieval Augmented Generation - RAG):**\n    *   Langchain allows you to easily integrate LLMs with your own data (documents, databases, APIs).\n    *   This enables LLMs to access and use information they weren\'t originally trained on, making their responses more relevant and accurate.\n    *   Key concepts here include **Document Loaders**, **Text Splitters**, **Vector Stores**, and **Retrievers**.\n\n2.  **Enabling LLMs to Interact with Their Environment (Agents and Tools):**\n    *   Langchain empowers LLMs to use **"tools"** – external functionalities like search engines, calculators, APIs, or even custom code.\n    *   **Agents** are LLMs that use these tools to reason and decide which tool to use next to accomplish a given task. This allows LLMs to go beyond just generating text and actively perform actions.\n\n3.  **Managing Conversations and State (Chains and Memory):**\n    *   **Chains** are sequences of calls to LLMs or other utilities. They allow you to combine multiple steps into a coherent workflow. For example, a chain might first retrieve relevant documents, then pass them to an LLM for summarization.\n    *   **Memory** components allow LLMs to retain context from previous interactions in a conversation, making them more effective for chatbots and dialogue-based applications.\n\n4.  **Abstraction and Modularity:**\n    *   Langchain provides a standardized interface for interacting with various LLM providers (OpenAI, Hugging Face, Anthropic, etc.).\n    *   Its modular design means you can pick and choose the components you need for your specific application.\n\n**Key Concepts in Langchain:**\n\n*   **LLMs:** The core language models themselves.\n*   **Prompts:** Templates for generating LLM inputs.\n*   **Chains:** Sequences of LLM calls and other operations.\n*   **Agents:** LLMs that use tools to make decisions and take actions.\n*   **Tools:** Functions or APIs that agents can use.\n*   **Document Loaders:** Mechanisms to load data from various sources.\n*   **Text Splitters:** Ways to break down large documents into smaller chunks.\n*   **Vector Stores:** Databases optimized for storing and searching embeddings (numerical representations of text).\n*   **Retrievers:** Components that fetch relevant documents from a vector store.\n*   **Memory:** Mechanisms for storing and recalling conversation history.\n\n**Why is Langchain Popular?**\n\n*   **Simplifies LLM Development:** It abstracts away much of the boilerplate code required to build LLM-powered applications.\n*   **Accelerates Prototyping:** Developers can quickly experiment with different LLM integrations and workflows.\n*   **Enables Advanced Functionality:** It makes it easier to build applications with features like RAG, agents, and conver ...

# %% [markdown]
# Static prompts

# %%
prompt = [
    ("system", "You are a Langchain expert."),
    ("user","What are the important topics to learn in Langchain ?")
]
result = llm.invoke(prompt)
print(result)
# Out:
# content="As a Langchain expert, I can tell you that Langchain is a rapidly evolving framework, and staying on top of its key components is crucial for building powerful LLM-powered applications. Here are the most important topics to learn in Langchain, categorized for clarity:\n\n**I. Core Concepts & Building Blocks:**\n\n*   **LLMs (Large Language Models):**\n    *   Understanding different LLM providers (OpenAI, Hugging Face, Anthropic, etc.) and how to interact with them.\n    *   Key concepts like prompts, tokens, temperature, and top-p sampling.\n    *   Finetuning and its implications (though Langchain primarily focuses on *using* pre-trained models).\n*   **Prompts:**\n    *   **Prompt Engineering:** The art and science of crafting effective prompts to guide LLMs.\n    *   **Prompt Templates:** How to dynamically create prompts with placeholders for context and variables.\n    *   **Chat Prompt Templates:** Specifically for conversational LLMs, handling roles (system, human, AI).\n*   **Chains:**\n    *   **Sequential Chains:** The fundamental concept of linking LLMs and other components together in a sequence.\n    *   **LLMChain:** The most basic chain, combining an LLM with a prompt.\n    *   **`SimpleSequentialChain`:** For simple, linear chains where output of one step is input to the next.\n    *   **`SequentialChain`:** For more complex chains with multiple inputs and outputs.\n    *   **Custom Chains:** Understanding how to build your own chain logic.\n*   **Agents:**\n    *   **What are Agents?** LLMs that can reason and decide which tools to use to accomplish a task.\n    *   **Tools:** Functions or APIs that an agent can call (e.g., search engines, calculators, databases).\n    *   **Agent Types:**\n        *   **`zero-shot-react-description`:** A common and powerful agent type.\n        *   **`conversational-react-description`:** For agents that maintain conversation history.\n        *   **`openai-functions`:** Leverages OpenAI's function calling capabilities.\n        *   **`openai-tools`:** Similar to `openai-functions` but for newer OpenAI models.\n    *   **Agent Executors:** The runtime that manages the agent's decision-making process.\n*   **Memory:**\n    *   **Purpose of Memory:** Allowing LLM applications to remember past interactions.\n    *   **Types of Memory:**\n        *   **`ConversationBufferMemory`:** Stores the raw conversation.\n        *   **`ConversationBufferWindowMemory`:** Stores a fixed number of recent messages.\n        *   **`ConversationSummaryMemory`:** Summarizes the conversation.\n        *   **`ConversationSummaryBufferMemory`:** Combines summarization with a buffer.\n        *   **`VectorStoreRetrieverMemory`:** Uses a vector store to retrieve relevant past interactions.\n    *   **Integrating Memory into Chains and Agents.**\n\n**II. Data Integration & Retrieval:**\n\n*   **Document Loaders:**\n    *   Loading data from various sources (files, websites, databases, APIs).\n    *   Understanding different loader implementations (e.g., `TextLoader`, `WebBaseLoader`, `PyPDFLoader`).\n*   **Text Splitters:**\n    *   Breaking down large documents into smaller, manageable chunks for LLM processing.\n    *   Different splitting strategies (character, recursive character, token-aware).\n*   **Vector Stores:**\n    *   **Embeddings:** Converting text into numerical vectors that capture semantic meaning.\n    *   **Vector Databases:** Storing and querying these embeddings efficiently (e.g., Chroma, Pinecone, FAISS, Weaviate).\n    *   **`VectorStoreRetriever`:** The core component for retrieving relevant documents based on a query embedding.\n*   **Retrieval Augmented Generation (RAG):**\n    *   The fundamental pattern of retrieving relevant information from a knowledge base and using it to augment LLM prompts.\n    *   Understanding the RAG pipeline: document loading -> splitting -> embedding -> storing -> retrieval -> generation.\n\n**III. Advanced & Specialized Topics:**\n\n*    ...
